# %%
import matplotlib.pyplot as plt  # 绘图库
from sklearn.datasets import make_blobs # 
import numpy as np

X, y = make_blobs(n_samples=1000,
                  n_features=2,
                  centers=2,
                  cluster_std=1.5,
                  random_state=1)

X
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-bbd22aa31de2> in <module>
#       1 import matplotlib.pyplot as plt  # 绘图库
# ----> 2 from sklearn.datasets import make_blobs #
#       3 import numpy as np
#       4
#       5 X, y = make_blobs(n_samples=1000,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\__init__.py in <module>
#      77     # later is linked to the OpenMP runtime to make it possible to introspect
#      78     # it and importing it first would fail if the OpenMP dll cannot be found.
# ---> 79     from . import (
#      80         __check_build,  # noqa: F401
#      81         _distributor_init,  # noqa: F401
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\_distributor_init.py in <module>
#      20     msvcp140_dll_filename = op.join(libs_path, "msvcp140.dll")
#      21     WinDLL(op.abspath(vcomp140_dll_filename))
# ---> 22     WinDLL(op.abspath(msvcp140_dll_filename))
#
# C:\ProgramData\Anaconda3\lib\ctypes\__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     379
#     380         if handle is None:
# --> 381             self._handle = _dlopen(self._name, mode)
#     382         else:
#     383             self._handle = handle
#
# FileNotFoundError: Could not find module 'C:\ProgramData\Anaconda3\lib\site-packages\sklearn\.libs\msvcp140.dll' (or one of its dependencies). Try using the full path with constructor syntax.

# %%
# %matplotlib inline

from sklearn.datasets import make_regression
import matplotlib.pyplot as plt

X, y = make_regression(n_features=1,effective_rank=0.1,noise=1)

plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression,SGDRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

lr = LinearRegression()

X_train,X_test,y_train,y_test = train_test_split(X,y)

lr.fit(X_train,y_train)

print("LR系数:",lr.coef_)
print("LR截距:",lr.intercept_)
print("LR训练集得分:",lr.score(X_train,y_train))
print("LR测试集得分:",lr.score(X_test,y_test))
y_pred = lr.predict(X_test)
print("LR测试集均方误差:",mean_squared_error(y_test,y_pred))
# Out:
# LR系数: [21.7637447]
# LR截距: 0.10169679947305034
# LR训练集得分: 0.8156257797535946
# LR测试集得分: 0.8525377889639807
# LR测试集均方误差: 1.0559052172833385

# %%
plt.scatter(X_test,y_test)
plt.plot(X_test,y_pred)

# %%
#%matplotlib inline

from sklearn.datasets import make_s_curve
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

X, y = make_s_curve()

data = pd.DataFrame(X,columns=["x1","x2","x3"])
data["y"] = y

sns.pairplot(data=data)

# %%
# %matplotlib notebook
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(5,5))
#创建3d绘图区域
ax = plt.axes(projection='3d',)

X, y = make_s_curve()

ax.scatter3D(X[:, 0],X[:, 1],X[:,2])
# Out:
# <img src="data:image/png;base64,..." width="500.48">

# %%
# %matplotlib notebook
#导入三维工具包mplot3d
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(5,5))
#创建3d绘图区域
ax = plt.axes(projection='3d',)

X, y = make_regression(n_features=2,effective_rank=0.1,tail_strength=0.2)

ax.scatter3D(X[:, 0],X[:, 1],y)
# Out:
# <img src="data:image/png;base64,..." width="500.48">

# %%
from sklearn.linear_model import LinearRegression,SGDRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

lr = LinearRegression()

X, y = make_regression(n_features=2,effective_rank=0.1,tail_strength=0.2,noise=0.5)
X_train,X_test,y_train,y_test = train_test_split(X,y)

lr.fit(X_train,y_train)

print("LR系数:",lr.coef_)
print("LR截距:",lr.intercept_)
print("LR训练集得分:",lr.score(X_train,y_train))
print("LR测试集得分:",lr.score(X_test,y_test))
y_pred = lr.predict(X_test)
print("LR测试集均方误差:",mean_squared_error(y_test,y_pred))
# Out:
# LR系数: [ 9.22330897 19.71953348]
# LR截距: -0.05809236463109467
# LR训练集得分: 0.934097219729859
# LR测试集得分: 0.9281340742605586
# LR测试集均方误差: 0.3573413069881896

# %%
# %matplotlib notebook
#导入三维工具包mplot3d
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(6,4))
#创建3d绘图区域
ax = plt.axes(projection='3d',)



ax.scatter3D(X_test[:, 0],X_test[:, 1],y_test)
ax.plot(X_test[:, 0],X_test[:, 1],y_pred)
# Out:
# <img src="data:image/png;base64,..." width="527.36">

# %%
y_pred.reshape(1,-1)
# Out:
# array([[-1.99765126,  2.20530658,  6.2311997 ,  3.21050922,  0.30654852,
#         -2.50595151, -1.4687447 , -4.61561597, -0.29475318, -1.26662042,
#          1.34904816,  0.18055634, -2.62505511,  2.09152983, -3.99437256,
#         -3.28062606, -2.87135526, -0.81201605, -2.67646184, -0.87811586,
#         -4.39519561,  3.59594732, -1.16791892,  2.64971869,  2.31889874]])
